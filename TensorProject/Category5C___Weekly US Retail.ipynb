# %% [markdown]
# <a href="https://colab.research.google.com/github/KangHwan-Cha/MyStudy/blob/main/TensorProject/Category5C___Weekly US Retail.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 2021년 10월 20일 신규 출제 문제

# %% [markdown]
# # Category 5
#
# Sequence (시계열) 데이터 다루기

# %% [markdown]
# ## 확인

# %% [markdown]
# 1. GPU 옵션 켜져 있는지 확인할 것!!! (수정 - 노트설정 - 하드웨어설정 (GPU))

# %% [markdown]
# ## 순서

# %% [markdown]
# 1. **import**: 필요한 모듈 import
# 2. **전처리**: 학습에 필요한 데이터 전처리를 수행합니다.
# 3. **모델링(model)**: 모델을 정의합니다.
# 4. **컴파일(compile)**: 모델을 생성합니다.
# 5. **학습 (fit)**: 모델을 학습시킵니다.

# %% [markdown]
# ## 문제

# %% [markdown]
# Build and train a neural network to predict the time indexed variable of the univariate US diesel prices (On - Highway) All types for the period of 1994 - 2021.
#
# Using a **window of past 10 observations of 1 feature** , train the model to predict the **next 10 observations** of that feature.
#
# ---
#
# HINT: If you follow all the rules mentioned above and throughout this
# question while training your neural network, there is a possibility that a
# validation **MAE of approximately 0.02 or less on the normalized validation
# dataset** may fetch you top marks.

# %% [markdown]
# ## 실습 예제 다운로드

# %%
import urllib
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense, Conv1D, LSTM, Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint

# 아래 2줄 코드는 넣지 말아 주세요!!!
url = 'https://www.dropbox.com/s/eduk281didil1km/Weekly_U.S.Diesel_Retail_Prices.csv?dl=1'
urllib.request.urlretrieve(url, 'Weekly_U.S.Diesel_Retail_Prices.csv')
# Out:
# ('Weekly_U.S.Diesel_Retail_Prices.csv',
#  <http.client.HTTPMessage at 0x7fbfc3e8ba30>)

# %% [markdown]
# ### Normalization

# %%
# This function normalizes the dataset using min max scaling.
# DO NOT CHANGE THIS CODE
def normalize_series(data, min, max):
    data = data - min
    data = data / max
    return data

# %% [markdown]
# ### Windowed Dataset 생성

# %%
# DO NOT CHANGE THIS.
def windowed_dataset(series, batch_size, n_past=10, n_future=10, shift=1):
    ds = tf.data.Dataset.from_tensor_slices(series)   # convert dataset
    ds = ds.window(size=n_past + n_future, shift=shift, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(n_past + n_future))
    ds = ds.map(lambda w: (w[:n_past], w[n_past:]))   # need to add who tester=> separate x, y value
    return ds.batch(batch_size).prefetch(1)

# %% [markdown]
# ### Dataset 로드

# %%
df = pd.read_csv('Weekly_U.S.Diesel_Retail_Prices.csv', infer_datetime_format=True, index_col='Week of', header=0)
df.head(20)
# Out:
#             Weekly U.S. No 2 Diesel Retail Prices Dollars per Gallon
# Week of
# 1994-03-21                                              1.106
# 1994-03-28                                              1.107
# 1994-04-04                                              1.109
# 1994-04-11                                              1.108
# 1994-04-18                                              1.105
# 1994-04-25                                              1.106
# 1994-05-02                                              1.104
# 1994-05-09                                              1.101
# 1994-05-16                                              1.099
# 1994-05-23                                              1.099
# 1994-05-30                                              1.098
# 1994-06-06                                              1.101
# 1994-06-13                                              1.098
# 1994-06-20                                              1.103
# 1994-06-27                                              1.108
# 1994-07-04                                              1.109
# 1994-07-11                                              1.110
# 1994-07-18                                              1.111
# 1994-07-25                                              1.111
# 1994-08-01                                              1.116

# %%
len(df)
# Out:
# 1424

# %%
# 특성 정의
N_FEATURES = len(df.columns)
N_FEATURES
# Out:
# 1

# %% [markdown]
# ### 정규화 및 데이터 분할

# %%
# 정규화 코드
data = df.values

data = normalize_series(data, data.min(axis=0), data.max(axis=0))

# 데이터 분할
SPLIT_TIME = int(len(data) * 0.8) # DO NOT CHANGE THIS
x_train = data[:SPLIT_TIME]
x_valid = data[SPLIT_TIME:]

# %%
x_train.shape, x_valid.shape
# Out:
# ((1139, 1), (285, 1))

# %%
BATCH_SIZE = 32  # 배치사이즈
N_PAST = 10      # 과거 데이터 (X)
N_FUTURE = 10    # 미래 데이터 (Y)
SHIFT = 1        # SHIFT    # windowed_dataset의 shift value

# %% [markdown]
# ### train / validation set 구성

# %%
train_set = windowed_dataset(series=x_train, batch_size=BATCH_SIZE,
                             n_past=N_PAST, n_future=N_FUTURE,
                             shift=SHIFT)

valid_set = windowed_dataset(series=x_valid, batch_size=BATCH_SIZE,
                             n_past=N_PAST, n_future=N_FUTURE,
                             shift=SHIFT)

# %% [markdown]
# ### 모델 구성

# %%
model = tf.keras.models.Sequential([
    Conv1D(filters=32, kernel_size=5, padding='causal', activation='relu', input_shape=[N_PAST, 1]),   # N_PAST: window size
    Bidirectional(LSTM(32, return_sequences=True)),
    Bidirectional(LSTM(32, return_sequences=True)),   # many to many # x: 10 / y: 10
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(N_FEATURES)
])

# %% [markdown]
# ### 체크포인트 생성

# %%
checkpoint_path = 'model/my_checkpoint.ckpt'
checkpoint = ModelCheckpoint(filepath=checkpoint_path,
                             save_weights_only=True,
                             save_best_only=True,
                             monitor='val_mae',
                             verbose=1)

# %% [markdown]
# ### 컴파일

# %%
optimizer = tf.keras.optimizers.Adam(0.0001)
model.compile(optimizer=optimizer, loss=tf.keras.losses.Huber(), metrics=['mae'])

# %% [markdown]
# ### 학습(train)

# %%
model.fit(train_set,
          validation_data=(valid_set),
          epochs=100,
          callbacks=[checkpoint])
# Out:
# Epoch 1/100
#      35/Unknown - 14s 11ms/step - loss: 0.0556 - mae: 0.2585
# Epoch 1: val_mae improved from inf to 0.33653, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 16s 66ms/step - loss: 0.0556 - mae: 0.2585 - val_loss: 0.0587 - val_mae: 0.3365
# Epoch 2/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0361 - mae: 0.1898
# Epoch 2: val_mae improved from 0.33653 to 0.27324, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0414 - mae: 0.2126 - val_loss: 0.0393 - val_mae: 0.2732
# Epoch 3/100
# 30/35 [========================>.....] - ETA: 0s - loss: 0.0209 - mae: 0.1423
# Epoch 3: val_mae improved from 0.27324 to 0.17944, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0255 - mae: 0.1655 - val_loss: 0.0182 - val_mae: 0.1794
# Epoch 4/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0118 - mae: 0.1223
# Epoch 4: val_mae improved from 0.17944 to 0.07738, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0125 - mae: 0.1261 - val_loss: 0.0050 - val_mae: 0.0774
# Epoch 5/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0089 - mae: 0.1150
# Epoch 5: val_mae improved from 0.07738 to 0.05528, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0088 - mae: 0.1131 - val_loss: 0.0026 - val_mae: 0.0553
# Epoch 6/100
# 30/35 [========================>.....] - ETA: 0s - loss: 0.0081 - mae: 0.1110
# Epoch 6: val_mae improved from 0.05528 to 0.05084, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 17ms/step - loss: 0.0078 - mae: 0.1071 - val_loss: 0.0021 - val_mae: 0.0508
# Epoch 7/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0064 - mae: 0.0970
# Epoch 7: val_mae improved from 0.05084 to 0.04804, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0063 - mae: 0.0954 - val_loss: 0.0018 - val_mae: 0.0480
# Epoch 8/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0049 - mae: 0.0841
# Epoch 8: val_mae improved from 0.04804 to 0.04562, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0048 - mae: 0.0830 - val_loss: 0.0016 - val_mae: 0.0456
# Epoch 9/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0037 - mae: 0.0719
# Epoch 9: val_mae improved from 0.04562 to 0.04338, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0036 - mae: 0.0706 - val_loss: 0.0015 - val_mae: 0.0434
# Epoch 10/100
# 30/35 [========================>.....] - ETA: 0s - loss: 0.0029 - mae: 0.0616
# Epoch 10: val_mae improved from 0.04338 to 0.04208, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0029 - mae: 0.0608 - val_loss: 0.0014 - val_mae: 0.0421
# Epoch 11/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0024 - mae: 0.0537
# Epoch 11: val_mae improved from 0.04208 to 0.04065, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 17ms/step - loss: 0.0024 - mae: 0.0537 - val_loss: 0.0013 - val_mae: 0.0406
# Epoch 12/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0021 - mae: 0.0479
# Epoch 12: val_mae improved from 0.04065 to 0.03916, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0021 - mae: 0.0479 - val_loss: 0.0013 - val_mae: 0.0392
# Epoch 13/100
# 30/35 [========================>.....] - ETA: 0s - loss: 0.0020 - mae: 0.0431
# Epoch 13: val_mae improved from 0.03916 to 0.03775, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0019 - mae: 0.0438 - val_loss: 0.0012 - val_mae: 0.0377
# Epoch 14/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0018 - mae: 0.0414
# Epoch 14: val_mae improved from 0.03775 to 0.03622, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0018 - mae: 0.0414 - val_loss: 0.0011 - val_mae: 0.0362
# Epoch 15/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0018 - mae: 0.0394
# Epoch 15: val_mae improved from 0.03622 to 0.03488, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0018 - mae: 0.0400 - val_loss: 0.0010 - val_mae: 0.0349
# Epoch 16/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0017 - mae: 0.0384
# Epoch 16: val_mae improved from 0.03488 to 0.03365, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0017 - mae: 0.0389 - val_loss: 9.7224e-04 - val_mae: 0.0336
# Epoch 17/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0017 - mae: 0.0376
# Epoch 17: val_mae improved from 0.03365 to 0.03256, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0016 - mae: 0.0380 - val_loss: 9.2128e-04 - val_mae: 0.0326
# Epoch 18/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0016 - mae: 0.0372
# Epoch 18: val_mae improved from 0.03256 to 0.03160, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0016 - mae: 0.0371 - val_loss: 8.7818e-04 - val_mae: 0.0316
# Epoch 19/100
# 30/35 [========================>.....] - ETA: 0s - loss: 0.0016 - mae: 0.0362
# Epoch 19: val_mae improved from 0.03160 to 0.03075, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0016 - mae: 0.0364 - val_loss: 8.4142e-04 - val_mae: 0.0307
# Epoch 20/100
# 30/35 [========================>.....] - ETA: 0s - loss: 0.0016 - mae: 0.0357
# Epoch 20: val_mae improved from 0.03075 to 0.03003, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0015 - mae: 0.0358 - val_loss: 8.1170e-04 - val_mae: 0.0300
# Epoch 21/100
# 30/35 [========================>.....] - ETA: 0s - loss: 0.0016 - mae: 0.0353
# Epoch 21: val_mae improved from 0.03003 to 0.02944, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0015 - mae: 0.0353 - val_loss: 7.8784e-04 - val_mae: 0.0294
# Epoch 22/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0015 - mae: 0.0349
# Epoch 22: val_mae improved from 0.02944 to 0.02895, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0015 - mae: 0.0349 - val_loss: 7.6846e-04 - val_mae: 0.0289
# Epoch 23/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0014 - mae: 0.0332
# Epoch 23: val_mae improved from 0.02895 to 0.02854, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0015 - mae: 0.0345 - val_loss: 7.5297e-04 - val_mae: 0.0285
# Epoch 24/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0014 - mae: 0.0329
# Epoch 24: val_mae improved from 0.02854 to 0.02821, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0342 - val_loss: 7.4081e-04 - val_mae: 0.0282
# Epoch 25/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0338
# Epoch 25: val_mae improved from 0.02821 to 0.02796, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0339 - val_loss: 7.3124e-04 - val_mae: 0.0280
# Epoch 26/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0014 - mae: 0.0334
# Epoch 26: val_mae improved from 0.02796 to 0.02777, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0014 - mae: 0.0337 - val_loss: 7.2384e-04 - val_mae: 0.0278
# Epoch 27/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0014 - mae: 0.0332
# Epoch 27: val_mae improved from 0.02777 to 0.02762, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0014 - mae: 0.0335 - val_loss: 7.1799e-04 - val_mae: 0.0276
# Epoch 28/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0331
# Epoch 28: val_mae improved from 0.02762 to 0.02752, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0333 - val_loss: 7.1364e-04 - val_mae: 0.0275
# Epoch 29/100
# 30/35 [========================>.....] - ETA: 0s - loss: 0.0014 - mae: 0.0330
# Epoch 29: val_mae improved from 0.02752 to 0.02744, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0331 - val_loss: 7.1030e-04 - val_mae: 0.0274
# Epoch 30/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0014 - mae: 0.0325
# Epoch 30: val_mae improved from 0.02744 to 0.02739, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0014 - mae: 0.0329 - val_loss: 7.0774e-04 - val_mae: 0.0274
# Epoch 31/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0014 - mae: 0.0324
# Epoch 31: val_mae improved from 0.02739 to 0.02736, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0014 - mae: 0.0328 - val_loss: 7.0613e-04 - val_mae: 0.0274
# Epoch 32/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0323
# Epoch 32: val_mae improved from 0.02736 to 0.02735, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0326 - val_loss: 7.0519e-04 - val_mae: 0.0273
# Epoch 33/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0014 - mae: 0.0320
# Epoch 33: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 13ms/step - loss: 0.0014 - mae: 0.0325 - val_loss: 7.0471e-04 - val_mae: 0.0274
# Epoch 34/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0321
# Epoch 34: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0014 - mae: 0.0324 - val_loss: 7.0459e-04 - val_mae: 0.0274
# Epoch 35/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0014 - mae: 0.0323
# Epoch 35: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0014 - mae: 0.0323 - val_loss: 7.0474e-04 - val_mae: 0.0274
# Epoch 36/100
# 30/35 [========================>.....] - ETA: 0s - loss: 0.0014 - mae: 0.0320
# Epoch 36: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0014 - mae: 0.0322 - val_loss: 7.0520e-04 - val_mae: 0.0275
# Epoch 37/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0014 - mae: 0.0316
# Epoch 37: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 13ms/step - loss: 0.0014 - mae: 0.0321 - val_loss: 7.0582e-04 - val_mae: 0.0275
# Epoch 38/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0014 - mae: 0.0320
# Epoch 38: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 13ms/step - loss: 0.0014 - mae: 0.0320 - val_loss: 7.0660e-04 - val_mae: 0.0276
# Epoch 39/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0013 - mae: 0.0314
# Epoch 39: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 13ms/step - loss: 0.0013 - mae: 0.0320 - val_loss: 7.0753e-04 - val_mae: 0.0276
# Epoch 40/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0013 - mae: 0.0313
# Epoch 40: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 13ms/step - loss: 0.0013 - mae: 0.0319 - val_loss: 7.0859e-04 - val_mae: 0.0277
# Epoch 41/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0013 - mae: 0.0314
# Epoch 41: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0318 - val_loss: 7.0957e-04 - val_mae: 0.0277
# Epoch 42/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0318
# Epoch 42: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0318 - val_loss: 7.1078e-04 - val_mae: 0.0278
# Epoch 43/100
# 30/35 [========================>.....] - ETA: 0s - loss: 0.0014 - mae: 0.0314
# Epoch 43: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 13ms/step - loss: 0.0013 - mae: 0.0317 - val_loss: 7.1182e-04 - val_mae: 0.0278
# Epoch 44/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0013 - mae: 0.0313
# Epoch 44: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0317 - val_loss: 7.1327e-04 - val_mae: 0.0279
# Epoch 45/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0317
# Epoch 45: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0317 - val_loss: 7.1432e-04 - val_mae: 0.0279
# Epoch 46/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0316
# Epoch 46: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0316 - val_loss: 7.1574e-04 - val_mae: 0.0280
# Epoch 47/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0013 - mae: 0.0311
# Epoch 47: val_mae did not improve from 0.02735
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0013 - mae: 0.0316 - val_loss: 7.1699e-04 - val_mae: 0.0280
# Epoch 48/100
# 30/35 [========================>.....] - ETA: 0s - loss: 0.0014 - mae: 0.0312
# Epoch 48: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 13ms/step - loss: 0.0013 - mae: 0.0315 - val_loss: 7.1811e-04 - val_mae: 0.0281
# Epoch 49/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0013 - mae: 0.0310
# Epoch 49: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0315 - val_loss: 7.1930e-04 - val_mae: 0.0281
# Epoch 50/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0013 - mae: 0.0308
# Epoch 50: val_mae did not improve from 0.02735
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0013 - mae: 0.0315 - val_loss: 7.2038e-04 - val_mae: 0.0282
# Epoch 51/100
# 30/35 [========================>.....] - ETA: 0s - loss: 0.0013 - mae: 0.0311
# Epoch 51: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 13ms/step - loss: 0.0013 - mae: 0.0315 - val_loss: 7.2153e-04 - val_mae: 0.0282
# Epoch 52/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0314
# Epoch 52: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0314 - val_loss: 7.2248e-04 - val_mae: 0.0283
# Epoch 53/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0012 - mae: 0.0297
# Epoch 53: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0314 - val_loss: 7.2345e-04 - val_mae: 0.0283
# Epoch 54/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0013 - mae: 0.0306
# Epoch 54: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0314 - val_loss: 7.2454e-04 - val_mae: 0.0283
# Epoch 55/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0013 - mae: 0.0309
# Epoch 55: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0314 - val_loss: 7.2543e-04 - val_mae: 0.0284
# Epoch 56/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0013 - mae: 0.0308
# Epoch 56: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0313 - val_loss: 7.2640e-04 - val_mae: 0.0284
# Epoch 57/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0313
# Epoch 57: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0313 - val_loss: 7.2727e-04 - val_mae: 0.0284
# Epoch 58/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0013 - mae: 0.0308
# Epoch 58: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0313 - val_loss: 7.2814e-04 - val_mae: 0.0285
# Epoch 59/100
# 30/35 [========================>.....] - ETA: 0s - loss: 0.0013 - mae: 0.0308
# Epoch 59: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0313 - val_loss: 7.2890e-04 - val_mae: 0.0285
# Epoch 60/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0312
# Epoch 60: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0312 - val_loss: 7.2965e-04 - val_mae: 0.0285
# Epoch 61/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0013 - mae: 0.0304
# Epoch 61: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0312 - val_loss: 7.3033e-04 - val_mae: 0.0285
# Epoch 62/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0312
# Epoch 62: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0312 - val_loss: 7.3099e-04 - val_mae: 0.0286
# Epoch 63/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0013 - mae: 0.0306
# Epoch 63: val_mae did not improve from 0.02735
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0013 - mae: 0.0312 - val_loss: 7.3163e-04 - val_mae: 0.0286
# Epoch 64/100
# 30/35 [========================>.....] - ETA: 0s - loss: 0.0013 - mae: 0.0306
# Epoch 64: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0312 - val_loss: 7.3226e-04 - val_mae: 0.0286
# Epoch 65/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0013 - mae: 0.0306
# Epoch 65: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0311 - val_loss: 7.3274e-04 - val_mae: 0.0286
# Epoch 66/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0012 - mae: 0.0298
# Epoch 66: val_mae did not improve from 0.02735
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0013 - mae: 0.0311 - val_loss: 7.3337e-04 - val_mae: 0.0287
# Epoch 67/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0012 - mae: 0.0293
# Epoch 67: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0311 - val_loss: 7.3366e-04 - val_mae: 0.0287
# Epoch 68/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0013 - mae: 0.0305
# Epoch 68: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0311 - val_loss: 7.3434e-04 - val_mae: 0.0287
# Epoch 69/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0013 - mae: 0.0302
# Epoch 69: val_mae did not improve from 0.02735
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0013 - mae: 0.0310 - val_loss: 7.3464e-04 - val_mae: 0.0287
# Epoch 70/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0310
# Epoch 70: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0310 - val_loss: 7.3522e-04 - val_mae: 0.0287
# Epoch 71/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0012 - mae: 0.0292
# Epoch 71: val_mae did not improve from 0.02735
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0013 - mae: 0.0310 - val_loss: 7.3527e-04 - val_mae: 0.0287
# Epoch 72/100
# 30/35 [========================>.....] - ETA: 0s - loss: 0.0013 - mae: 0.0304
# Epoch 72: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0310 - val_loss: 7.3582e-04 - val_mae: 0.0287
# Epoch 73/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0013 - mae: 0.0304
# Epoch 73: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0310 - val_loss: 7.3587e-04 - val_mae: 0.0287
# Epoch 74/100
# 30/35 [========================>.....] - ETA: 0s - loss: 0.0013 - mae: 0.0304
# Epoch 74: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0309 - val_loss: 7.3622e-04 - val_mae: 0.0288
# Epoch 75/100
# 30/35 [========================>.....] - ETA: 0s - loss: 0.0013 - mae: 0.0303
# Epoch 75: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0309 - val_loss: 7.3599e-04 - val_mae: 0.0288
# Epoch 76/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0012 - mae: 0.0291
# Epoch 76: val_mae did not improve from 0.02735
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0013 - mae: 0.0309 - val_loss: 7.3672e-04 - val_mae: 0.0288
# Epoch 77/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0013 - mae: 0.0303
# Epoch 77: val_mae did not improve from 0.02735
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0013 - mae: 0.0309 - val_loss: 7.3666e-04 - val_mae: 0.0288
# Epoch 78/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0013 - mae: 0.0303
# Epoch 78: val_mae did not improve from 0.02735
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0013 - mae: 0.0309 - val_loss: 7.3714e-04 - val_mae: 0.0288
# Epoch 79/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0308
# Epoch 79: val_mae did not improve from 0.02735
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0013 - mae: 0.0308 - val_loss: 7.3709e-04 - val_mae: 0.0288
# Epoch 80/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0308
# Epoch 80: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0308 - val_loss: 7.3754e-04 - val_mae: 0.0288
# Epoch 81/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0013 - mae: 0.0299
# Epoch 81: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0308 - val_loss: 7.3746e-04 - val_mae: 0.0288
# Epoch 82/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0308
# Epoch 82: val_mae did not improve from 0.02735
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0013 - mae: 0.0308 - val_loss: 7.3792e-04 - val_mae: 0.0288
# Epoch 83/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0308
# Epoch 83: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0308 - val_loss: 7.3807e-04 - val_mae: 0.0288
# Epoch 84/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0013 - mae: 0.0301
# Epoch 84: val_mae did not improve from 0.02735
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0013 - mae: 0.0307 - val_loss: 7.3822e-04 - val_mae: 0.0288
# Epoch 85/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0013 - mae: 0.0301
# Epoch 85: val_mae did not improve from 0.02735
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0013 - mae: 0.0307 - val_loss: 7.3812e-04 - val_mae: 0.0289
# Epoch 86/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0012 - mae: 0.0289
# Epoch 86: val_mae did not improve from 0.02735
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0013 - mae: 0.0307 - val_loss: 7.3860e-04 - val_mae: 0.0289
# Epoch 87/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0012 - mae: 0.0301
# Epoch 87: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0307 - val_loss: 7.3861e-04 - val_mae: 0.0289
# Epoch 88/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0012 - mae: 0.0297
# Epoch 88: val_mae did not improve from 0.02735
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0013 - mae: 0.0307 - val_loss: 7.3885e-04 - val_mae: 0.0289
# Epoch 89/100
# 30/35 [========================>.....] - ETA: 0s - loss: 0.0013 - mae: 0.0300
# Epoch 89: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0306 - val_loss: 7.3887e-04 - val_mae: 0.0289
# Epoch 90/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0012 - mae: 0.0296
# Epoch 90: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0306 - val_loss: 7.3947e-04 - val_mae: 0.0289
# Epoch 91/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0012 - mae: 0.0300
# Epoch 91: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0306 - val_loss: 7.3976e-04 - val_mae: 0.0289
# Epoch 92/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0012 - mae: 0.0300
# Epoch 92: val_mae did not improve from 0.02735
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0013 - mae: 0.0306 - val_loss: 7.4024e-04 - val_mae: 0.0289
# Epoch 93/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0012 - mae: 0.0292
# Epoch 93: val_mae did not improve from 0.02735
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0013 - mae: 0.0306 - val_loss: 7.3990e-04 - val_mae: 0.0289
# Epoch 94/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0012 - mae: 0.0299
# Epoch 94: val_mae did not improve from 0.02735
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0012 - mae: 0.0305 - val_loss: 7.4023e-04 - val_mae: 0.0289
# Epoch 95/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0012 - mae: 0.0299
# Epoch 95: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0012 - mae: 0.0305 - val_loss: 7.4026e-04 - val_mae: 0.0289
# Epoch 96/100
# 30/35 [========================>.....] - ETA: 0s - loss: 0.0013 - mae: 0.0298
# Epoch 96: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0012 - mae: 0.0305 - val_loss: 7.4049e-04 - val_mae: 0.0289
# Epoch 97/100
# 30/35 [========================>.....] - ETA: 0s - loss: 0.0012 - mae: 0.0298
# Epoch 97: val_mae did not improve from 0.02735
# 35/35 [==============================] - 0s 13ms/step - loss: 0.0012 - mae: 0.0305 - val_loss: 7.4094e-04 - val_mae: 0.0290
# Epoch 98/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0012 - mae: 0.0291
# Epoch 98: val_mae did not improve from 0.02735
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0012 - mae: 0.0305 - val_loss: 7.4088e-04 - val_mae: 0.0290
# Epoch 99/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0012 - mae: 0.0298
# Epoch 99: val_mae did not improve from 0.02735
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0012 - mae: 0.0304 - val_loss: 7.4057e-04 - val_mae: 0.0289
# Epoch 100/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0012 - mae: 0.0290
# Epoch 100: val_mae did not improve from 0.02735
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0012 - mae: 0.0304 - val_loss: 7.4095e-04 - val_mae: 0.0290

# %% [markdown]
# ### 가중치 로드

# %%
model.load_weights(checkpoint_path)

# %%
model.evaluate(valid_set)
# Out:
# 9/9 [==============================] - 0s 9ms/step - loss: 7.0519e-04 - mae: 0.0273
# [0.0007051890133880079, 0.027347879484295845]
