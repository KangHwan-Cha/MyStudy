# %% [markdown]
# <a href="https://colab.research.google.com/github/KangHwan-Cha/MyStudy/blob/main/TensorProject/Category5B__NewProject_HEPC-training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Import

# %%
import urllib
import os
import zipfile
import pandas as pd

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, Dense, LSTM, Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
def download_and_extract_data():
    url = 'https://storage.googleapis.com/download.tensorflow.org/data/certificate/household_power.zip'
    urllib.request.urlretrieve(url, 'household_power.zip')
    with zipfile.ZipFile('household_power.zip', 'r') as zip_ref:
        zip_ref.extractall()

# %%
download_and_extract_data()

# %%
df = pd.read_csv('household_power_consumption.csv', sep=',', infer_datetime_format=True, index_col='datetime', header=0)
df.head(5)
# Out:
#                      Global_active_power  Global_reactive_power  Voltage  \
# datetime
# 2006-12-16 17:24:00                4.216                  0.418   234.84
# 2006-12-16 17:25:00                5.360                  0.436   233.63
# 2006-12-16 17:26:00                5.374                  0.498   233.29
# 2006-12-16 17:27:00                5.388                  0.502   233.74
# 2006-12-16 17:28:00                3.666                  0.528   235.68
#
#                      Global_intensity  Sub_metering_1  Sub_metering_2  \
# datetime
# 2006-12-16 17:24:00              18.4             0.0             1.0
# 2006-12-16 17:25:00              23.0             0.0             1.0
# 2006-12-16 17:26:00              23.0             0.0             2.0
# 2006-12-16 17:27:00              23.0             0.0             1.0
# 2006-12-16 17:28:00              15.8             0.0             1.0
#
#                      Sub_metering_3
# datetime
# 2006-12-16 17:24:00            17.0
# 2006-12-16 17:25:00            16.0
# 2006-12-16 17:26:00            17.0
# 2006-12-16 17:27:00            17.0
# 2006-12-16 17:28:00            17.0

# %% [markdown]
# ### Data Nomalization

# %%
def normalize_series(data, min, max):
    data = data - min
    data = data / max
    return data

# %%
# FEATURES에 데이터프레임의 Column 개수 대입
N_FEATURES = len(df.columns)

# 데이터프레임을 numpy array으로 가져와 data에 대입
data = df.values

# 데이터 정규화
data = normalize_series(data, data.min(axis=0), data.max(axis=0))
data
# Out:
# array([[0.43377912, 0.47826087, 0.04036551, ..., 0.        , 0.01282051,
#         0.85      ],
#        [0.55716135, 0.49885584, 0.0355582 , ..., 0.        , 0.01282051,
#         0.8       ],
#        [0.55867127, 0.56979405, 0.03420739, ..., 0.        , 0.02564103,
#         0.85      ],
#        ...,
#        [0.03710095, 0.        , 0.05983313, ..., 0.        , 0.        ,
#         0.        ],
#        [0.03559103, 0.        , 0.06515693, ..., 0.        , 0.        ,
#         0.        ],
#        [0.03774806, 0.        , 0.06730234, ..., 0.        , 0.01282051,
#         0.        ]])

# %%
pd.DataFrame(data).describe()
# Out:
#                   0             1             2             3             4  \
# count  86400.000000  86400.000000  86400.000000  86400.000000  86400.000000
# mean       0.156411      0.147141      0.064697      0.152278      0.016950
# std        0.144040      0.134578      0.013900      0.139343      0.086787
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.021786      0.000000      0.055344      0.024752      0.000000
# 50%        0.131795      0.132723      0.065713      0.123762      0.000000
# 75%        0.239431      0.224256      0.074652      0.227723      0.000000
# max        0.979077      1.000000      0.107350      0.980198      1.000000
#
#                   5             6
# count  86400.000000  86400.000000
# mean       0.024085      0.375711
# std        0.097022      0.433595
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.012821      0.850000
# max        1.000000      1.000000

# %%
split_time = int(len(data) * 0.8)
split_time
# Out:
# 69120

# %%
x_train = data[:split_time]
x_valid = data[split_time:]

# %% [markdown]
# ### Windowed Dataset 생성

# %%
def windowed_dataset(series, batch_size, n_past=24, n_future=24, shift=1):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(size=(n_past + n_future), shift = shift, drop_remainder = True)
    ds = ds.flat_map(lambda w: w.batch(n_past + n_future))
    ds = ds.shuffle(len(series))
    ds = ds.map(
        lambda w: (w[:n_past], w[n_past:])   # w[:n_past] => x / w[n_past:] => y
    )
    return ds.batch(batch_size).prefetch(1)

# %%
# 다음 4개의 옵션은 주어 집니다.
BATCH_SIZE = 32 # 변경 가능하나 더 올리는 것은 비추 (내리는 것은 가능하나 시간 오래 걸림)
N_PAST = 24 # 변경 불가.
N_FUTURE = 24 # 변경 불가.
SHIFT = 1 # 변경 불가.

# %%
train_set = windowed_dataset(series=x_train, 
                             batch_size=BATCH_SIZE,
                             n_past=N_PAST, 
                             n_future=N_FUTURE,
                             shift=SHIFT)

valid_set = windowed_dataset(series=x_valid, 
                             batch_size=BATCH_SIZE,
                             n_past=N_PAST, 
                             n_future=N_FUTURE,
                             shift=SHIFT)

# %%
train_set
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None))>

# %%
model = Sequential([
    Conv1D(filters=32,
           kernel_size=3,
           padding='causal',
           activation='relu',
           input_shape=[N_PAST, 7]),
    Bidirectional(LSTM(32, return_sequences=True)),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(N_FEATURES)
])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_5 (Conv1D)           (None, 24, 32)            704
#
#  bidirectional_4 (Bidirectio  (None, 24, 64)           16640
#  nal)
#
#  dense_15 (Dense)            (None, 24, 32)            2080
#
#  dense_16 (Dense)            (None, 24, 16)            528
#
#  dense_17 (Dense)            (None, 24, 7)             119
#
# =================================================================
# Total params: 20,071
# Trainable params: 20,071
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_path = 'my_checkpoint.ckpt'
checkpoint = ModelCheckpoint(filepath=checkpoint_path,
                             save_weights_only=True,
                             save_best_only=True,
                             monitor='val_loss',
                             verbose=1
                             )

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.00005)
model.compile(loss='mae',
              optimizer=optimizer,
              metrics=['mae']
              )

# %%
model.fit(train_set,
          validation_data=(valid_set),
          epochs=20,
          callbacks=[checkpoint])
# Out:
# Epoch 1/20
#    2154/Unknown - 32s 10ms/step - loss: 0.0750 - mae: 0.0750
# Epoch 1: val_loss improved from inf to 0.05563, saving model to my_checkpoint.ckpt
# 2159/2159 [==============================] - 38s 13ms/step - loss: 0.0750 - mae: 0.0750 - val_loss: 0.0556 - val_mae: 0.0556
# Epoch 2/20
# 2159/2159 [==============================] - ETA: 0s - loss: 0.0537 - mae: 0.0537
# Epoch 2: val_loss improved from 0.05563 to 0.05075, saving model to my_checkpoint.ckpt
# 2159/2159 [==============================] - 35s 13ms/step - loss: 0.0537 - mae: 0.0537 - val_loss: 0.0508 - val_mae: 0.0508
# Epoch 3/20
# 2155/2159 [============================>.] - ETA: 0s - loss: 0.0503 - mae: 0.0503
# Epoch 3: val_loss improved from 0.05075 to 0.04881, saving model to my_checkpoint.ckpt
# 2159/2159 [==============================] - 36s 13ms/step - loss: 0.0503 - mae: 0.0503 - val_loss: 0.0488 - val_mae: 0.0488
# Epoch 4/20
# 2154/2159 [============================>.] - ETA: 0s - loss: 0.0488 - mae: 0.0488
# Epoch 4: val_loss improved from 0.04881 to 0.04783, saving model to my_checkpoint.ckpt
# 2159/2159 [==============================] - 35s 13ms/step - loss: 0.0488 - mae: 0.0488 - val_loss: 0.0478 - val_mae: 0.0478
# Epoch 5/20
# 2159/2159 [==============================] - ETA: 0s - loss: 0.0476 - mae: 0.0476
# Epoch 5: val_loss improved from 0.04783 to 0.04653, saving model to my_checkpoint.ckpt
# 2159/2159 [==============================] - 35s 13ms/step - loss: 0.0476 - mae: 0.0476 - val_loss: 0.0465 - val_mae: 0.0465
# Epoch 6/20
# 2154/2159 [============================>.] - ETA: 0s - loss: 0.0462 - mae: 0.0462
# Epoch 6: val_loss improved from 0.04653 to 0.04523, saving model to my_checkpoint.ckpt
# 2159/2159 [==============================] - 35s 13ms/step - loss: 0.0462 - mae: 0.0462 - val_loss: 0.0452 - val_mae: 0.0452
# Epoch 7/20
# 2156/2159 [============================>.] - ETA: 0s - loss: 0.0451 - mae: 0.0451
# Epoch 7: val_loss improved from 0.04523 to 0.04427, saving model to my_checkpoint.ckpt
# 2159/2159 [==============================] - 34s 13ms/step - loss: 0.0451 - mae: 0.0451 - val_loss: 0.0443 - val_mae: 0.0443
# Epoch 8/20
# 2155/2159 [============================>.] - ETA: 0s - loss: 0.0444 - mae: 0.0444
# Epoch 8: val_loss improved from 0.04427 to 0.04395, saving model to my_checkpoint.ckpt
# 2159/2159 [==============================] - 35s 13ms/step - loss: 0.0444 - mae: 0.0444 - val_loss: 0.0440 - val_mae: 0.0440
# Epoch 9/20
# 2156/2159 [============================>.] - ETA: 0s - loss: 0.0440 - mae: 0.0440
# Epoch 9: val_loss improved from 0.04395 to 0.04355, saving model to my_checkpoint.ckpt
# 2159/2159 [==============================] - 35s 13ms/step - loss: 0.0440 - mae: 0.0440 - val_loss: 0.0436 - val_mae: 0.0436
# Epoch 10/20
# 2156/2159 [============================>.] - ETA: 0s - loss: 0.0437 - mae: 0.0437
# Epoch 10: val_loss improved from 0.04355 to 0.04333, saving model to my_checkpoint.ckpt
# 2159/2159 [==============================] - 35s 13ms/step - loss: 0.0437 - mae: 0.0437 - val_loss: 0.0433 - val_mae: 0.0433
# Epoch 11/20
# 2157/2159 [============================>.] - ETA: 0s - loss: 0.0433 - mae: 0.0433
# Epoch 11: val_loss improved from 0.04333 to 0.04323, saving model to my_checkpoint.ckpt
# 2159/2159 [==============================] - 35s 13ms/step - loss: 0.0434 - mae: 0.0434 - val_loss: 0.0432 - val_mae: 0.0432
# Epoch 12/20
# 2159/2159 [==============================] - ETA: 0s - loss: 0.0431 - mae: 0.0431
# Epoch 12: val_loss improved from 0.04323 to 0.04280, saving model to my_checkpoint.ckpt
# 2159/2159 [==============================] - 35s 13ms/step - loss: 0.0431 - mae: 0.0431 - val_loss: 0.0428 - val_mae: 0.0428
# Epoch 13/20
# 2159/2159 [==============================] - ETA: 0s - loss: 0.0429 - mae: 0.0429
# Epoch 13: val_loss improved from 0.04280 to 0.04275, saving model to my_checkpoint.ckpt
# 2159/2159 [==============================] - 35s 13ms/step - loss: 0.0429 - mae: 0.0429 - val_loss: 0.0428 - val_mae: 0.0428
# Epoch 14/20
# 2155/2159 [============================>.] - ETA: 0s - loss: 0.0427 - mae: 0.0427
# Epoch 14: val_loss improved from 0.04275 to 0.04272, saving model to my_checkpoint.ckpt
# 2159/2159 [==============================] - 35s 13ms/step - loss: 0.0427 - mae: 0.0427 - val_loss: 0.0427 - val_mae: 0.0427
# Epoch 15/20
# 2154/2159 [============================>.] - ETA: 0s - loss: 0.0426 - mae: 0.0426
# Epoch 15: val_loss improved from 0.04272 to 0.04250, saving model to my_checkpoint.ckpt
# 2159/2159 [==============================] - 35s 13ms/step - loss: 0.0426 - mae: 0.0426 - val_loss: 0.0425 - val_mae: 0.0425
# Epoch 16/20
# 2158/2159 [============================>.] - ETA: 0s - loss: 0.0424 - mae: 0.0424
# Epoch 16: val_loss improved from 0.04250 to 0.04237, saving model to my_checkpoint.ckpt
# 2159/2159 [==============================] - 36s 13ms/step - loss: 0.0424 - mae: 0.0424 - val_loss: 0.0424 - val_mae: 0.0424
# Epoch 17/20
# 2159/2159 [==============================] - ETA: 0s - loss: 0.0423 - mae: 0.0423
# Epoch 17: val_loss improved from 0.04237 to 0.04207, saving model to my_checkpoint.ckpt
# 2159/2159 [==============================] - 35s 13ms/step - loss: 0.0423 - mae: 0.0423 - val_loss: 0.0421 - val_mae: 0.0421
# Epoch 18/20
# 2157/2159 [============================>.] - ETA: 0s - loss: 0.0422 - mae: 0.0422
# Epoch 18: val_loss did not improve from 0.04207
# 2159/2159 [==============================] - 35s 13ms/step - loss: 0.0422 - mae: 0.0422 - val_loss: 0.0422 - val_mae: 0.0422
# Epoch 19/20
# 2159/2159 [==============================] - ETA: 0s - loss: 0.0421 - mae: 0.0421
# Epoch 19: val_loss improved from 0.04207 to 0.04201, saving model to my_checkpoint.ckpt
# 2159/2159 [==============================] - 35s 13ms/step - loss: 0.0421 - mae: 0.0421 - val_loss: 0.0420 - val_mae: 0.0420
# Epoch 20/20
# 2155/2159 [============================>.] - ETA: 0s - loss: 0.0420 - mae: 0.0420
# Epoch 20: val_loss improved from 0.04201 to 0.04199, saving model to my_checkpoint.ckpt
# 2159/2159 [==============================] - 35s 13ms/step - loss: 0.0420 - mae: 0.0420 - val_loss: 0.0420 - val_mae: 0.0420

# %%
model.load_weights(checkpoint_path)

# %%
model.evaluate(valid_set)
# Out:
# 539/539 [==============================] - 6s 7ms/step - loss: 0.0420 - mae: 0.0420
# [0.041994281113147736, 0.04199425131082535]
