# %% [markdown]
# <a href="https://colab.research.google.com/github/KangHwan-Cha/MyStudy/blob/main/TensorProject/Category3B__CNN-cats vs dogs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Category 3 - Cats vs Dogs 분류
#
# * Convolution Neural network 활용한 분류 모델 (Classification)
# * tensorflow-datasets 를 활용한 데이터 전처리

# %% [markdown]
# ## 확인

# %% [markdown]
# 1. GPU 옵션 켜져 있는지 확인할 것!!! (수정 - 노트설정 - 하드웨어설정 (GPU))

# %% [markdown]
# ## 순서

# %% [markdown]
# 1. **import**: 필요한 모듈 import
# 2. **전처리**: 학습에 필요한 데이터 전처리를 수행합니다.
# 3. **모델링(model)**: 모델을 정의합니다.
# 4. **컴파일(compile)**: 모델을 생성합니다.
# 5. **학습 (fit)**: 모델을 학습시킵니다.

# %% [markdown]
# ## 문제

# %% [markdown]
# Computer Vision with CNNs
# <br>
# <br>For this exercise you will build a cats v dogs classifier
# <br>using the Cats v Dogs dataset from TFDS.
# <br>Be sure to use the final layer as shown
# <br>    **(Dense, 2 neurons, softmax activation)**
# <br>
# <br>The testing infrastructre will **resize all images to 224x224**
# <br>with **3 bytes of color depth**. Make sure your input layer trains
# <br>images to that specification, or the tests will fail.
# <br>
# <br>Make sure your output layer is exactly as specified here, or the
# <br>tests will fail.
#
# ----------------------------------------
# <br>이 연습에서는 cats v dogs 분류기를 만들 것입니다.
# TFDS의 Cats v Dogs 데이터 세트 사용.
# <br> 그림과 같이 최종 레이어를 사용하십시오
# <br> **(Dense, 뉴런 2 개, activation='softmax')**
# <br>
# <br> 테스트 인프라는 **모든 이미지의 크기를 224x224로 조정합니다(컬러사진)**. 입력 레이어를 확인하십시오

# %%
import tensorflow_datasets as tfds
import tensorflow as tf

from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# ## Load Dataset

# %% [markdown]
# **tensorflow-datasets**를 활용합니다.

# %% [markdown]
# * [Cats vs Dogs 데이터셋 문서 보기](https://www.tensorflow.org/datasets/catalog/cats_vs_dogs?hl=ko)
#
# * [tensorflow-datasets 다루기](https://www.tensorflow.org/datasets/splits?hl=ko)

# %% [markdown]
# **시험에서 주어지는 데이터셋 로드 형태**
#
# * 예전 방식이므로 아래처럼 주어지는 코드를 과감히 삭제 후, 아래 제공되는 방식으로 변경합니다.

# %%
dataset_name = 'cats_vs_dogs'
train_dataset = tfds.load(name=dataset_name, split='train')
# Out:
# Downloading and preparing dataset 786.68 MiB (download: 786.68 MiB, generated: Unknown size, total: 786.68 MiB) to /root/tensorflow_datasets/cats_vs_dogs/4.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/23262 [00:00<?, ? examples/s]
# WARNING:absl:1738 images were corrupted and were skipped
# Shuffling /root/tensorflow_datasets/cats_vs_dogs/4.0.0.incompleteMIBATT/cats_vs_dogs-train.tfrecord*...:   0%|…
# Dataset cats_vs_dogs downloaded and prepared to /root/tensorflow_datasets/cats_vs_dogs/4.0.0. Subsequent calls will reuse this data.

# %%
dataset_name = 'cats_vs_dogs'

# 처음 80%의 데이터만 사용
train_dataset = tfds.load(name=dataset_name, split='train[:80%]')

# 최근 20%의 데이터만 사용
valid_dataset = tfds.load(name=dataset_name, split='train[80%:]')

# %% [markdown]
# 시험에서 요구하는 **전처리 요구 조건**은 다음과 같습니다.
#
# 1. 이미지 정규화 (Normalization)
# 2. 이미지 사이즈 맞추기: (224 X 224)
# 3. image(x), label(y)를 분할

# %% [markdown]
# **[실습코드]**

# %%
for data in train_dataset.take(3):
  x = data['image'] / 255
  y = data['label']
  x = tf.image.resize(x, size=(224, 224))  # ★ image size 변경
# Out:
# (224, 224, 3)
# tf.Tensor(1, shape=(), dtype=int64)
# (224, 224, 3)
# tf.Tensor(1, shape=(), dtype=int64)
# (224, 224, 3)
# tf.Tensor(1, shape=(), dtype=int64)

# %%
def preprocess(data):
  x = data['image'] / 255
  y = data['label']
  x = tf.image.resize(x, size=(224, 224))
  return x, y

# %%
def preprocess(data):
    # x, y 데이터를 정의합니다.
    x = data['image']
    y = data['label']
    # image 정규화(Normalization)
    x = x / 255
    # 사이즈를 (224, 224)로 변환합니다.
    x = tf.image.resize(x, size=(224, 224))
    # x, y  데이터를 return 합니다.
    return x, y

# %% [markdown]
# 만든 전처리 함수(preprocessing)를 **dataset에 mapping**하고, **batch_size도 지정**합니다.

# %%
batch_size=32

# %%
train_data = train_dataset.map(preprocess).batch(batch_size)
valid_data = valid_dataset.map(preprocess).batch(batch_size)

# %% [markdown]
# ## 모델 정의 (Sequential)

# %% [markdown]
# 이제 Modeling을 할 차례입니다.
#
# `Sequential` 모델 안에서 층을 깊게 쌓아 올려 주면 됩니다.
#
# 1. `input_shape`는 (height, width, color_channel)입니다. cats vs dogs 문제에서는 (224, 224, 3) 이 됩니다.
# 2. 깊은 출력층과 더 많은 Layer를 쌓습니다.
# 3. Dense Layer에 `activation='relu'`를 적용합니다.
# 4. 분류(Classification)의 마지막 층의 출력 숫자는 분류하고자 하는 클래스 갯수와 **같아야** 합니다.

# %%
model = Sequential([
    Conv2D(32, (3, 3), input_shape=(224, 224, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(256, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(256, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dropout(0.5),
    Dense(512, activation='relu'),
    Dense(128, activation='relu'),
    Dense(2, activation='softmax'),
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 256)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 10, 10, 256)       590080
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 6400)              0
#
#  dropout (Dropout)           (None, 6400)              0
#
#  dense (Dense)               (None, 512)               3277312
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  dense_2 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 4,321,730
# Trainable params: 4,321,730
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 컴파일 (compile)

# %% [markdown]
# 1. `optimizer`는 가장 최적화가 잘되는 알고리즘인 'adam'을 사용합니다.
# 2. `loss`설정
#   * 출력층 activation이 `sigmoid` 인 경우: `binary_crossentropy`
#   * 출력층 activation이 `softmax` 인 경우:
#     * 원핫인코딩(O): `categorical_crossentropy`
#     * 원핫인코딩(X): `sparse_categorical_crossentropy`)
# 3. `metrics`를 'acc' 혹은 'accuracy'로 지정하면, 학습시 정확도를 모니터링 할 수 있습니다.

# %% [markdown]
# model.compile()

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['acc'])

# %% [markdown]
# ## ModelCheckpoint: 체크포인트 생성

# %% [markdown]
# `val_loss` 기준으로 epoch 마다 최적의 모델을 저장하기 위하여, ModelCheckpoint를 만듭니다.
# * `checkpoint_path`는 모델이 저장될 파일 명을 설정합니다.
# * `ModelCheckpoint`을 선언하고, 적절한 옵션 값을 지정합니다.

# %%
checkpoint_path = "my_checkpoint.ckpt"
checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             save_weights_only=True, 
                             save_best_only=True, 
                             monitor='val_loss', 
                             verbose=1)

# %% [markdown]
# ## 학습 (fit)

# %% [markdown]
# 1. `validation_data`를 반드시 지정합니다.
# 2. `epochs`을 적절하게 지정합니다.
# 3. `callbacks`에 바로 위에서 만든 checkpoint를 지정합니다.

# %%
model.fit(train_data,
          validation_data=(valid_data),
          epochs=20,
          callbacks=[checkpoint],
          )
# Out:
# Epoch 1/20
# 582/582 [==============================] - ETA: 0s - loss: 0.6887 - acc: 0.5364
# Epoch 1: val_loss improved from inf to 0.69044, saving model to my_checkpoint.ckpt
# 582/582 [==============================] - 57s 83ms/step - loss: 0.6887 - acc: 0.5364 - val_loss: 0.6904 - val_acc: 0.5411
# Epoch 2/20
# 581/582 [============================>.] - ETA: 0s - loss: 0.6270 - acc: 0.6518
# Epoch 2: val_loss improved from 0.69044 to 0.55240, saving model to my_checkpoint.ckpt
# 582/582 [==============================] - 49s 83ms/step - loss: 0.6270 - acc: 0.6518 - val_loss: 0.5524 - val_acc: 0.7229
# Epoch 3/20
# 581/582 [============================>.] - ETA: 0s - loss: 0.5064 - acc: 0.7561
# Epoch 3: val_loss improved from 0.55240 to 0.45062, saving model to my_checkpoint.ckpt
# 582/582 [==============================] - 47s 81ms/step - loss: 0.5063 - acc: 0.7561 - val_loss: 0.4506 - val_acc: 0.7872
# Epoch 4/20
# 581/582 [============================>.] - ETA: 0s - loss: 0.4184 - acc: 0.8073
# Epoch 4: val_loss improved from 0.45062 to 0.41829, saving model to my_checkpoint.ckpt
# 582/582 [==============================] - 48s 83ms/step - loss: 0.4182 - acc: 0.8074 - val_loss: 0.4183 - val_acc: 0.8067
# Epoch 5/20
# 581/582 [============================>.] - ETA: 0s - loss: 0.3447 - acc: 0.8488
# Epoch 5: val_loss improved from 0.41829 to 0.34584, saving model to my_checkpoint.ckpt
# 582/582 [==============================] - 48s 82ms/step - loss: 0.3445 - acc: 0.8490 - val_loss: 0.3458 - val_acc: 0.8403
# Epoch 6/20
# 581/582 [============================>.] - ETA: 0s - loss: 0.2958 - acc: 0.8735
# Epoch 6: val_loss did not improve from 0.34584
# 582/582 [==============================] - 49s 83ms/step - loss: 0.2957 - acc: 0.8736 - val_loss: 0.3846 - val_acc: 0.8300
# Epoch 7/20
# 581/582 [============================>.] - ETA: 0s - loss: 0.2453 - acc: 0.8986
# Epoch 7: val_loss improved from 0.34584 to 0.30191, saving model to my_checkpoint.ckpt
# 582/582 [==============================] - 48s 82ms/step - loss: 0.2454 - acc: 0.8985 - val_loss: 0.3019 - val_acc: 0.8680
# Epoch 8/20
# 581/582 [============================>.] - ETA: 0s - loss: 0.2109 - acc: 0.9126
# Epoch 8: val_loss improved from 0.30191 to 0.29634, saving model to my_checkpoint.ckpt
# 582/582 [==============================] - 48s 82ms/step - loss: 0.2108 - acc: 0.9126 - val_loss: 0.2963 - val_acc: 0.8717
# Epoch 9/20
# 581/582 [============================>.] - ETA: 0s - loss: 0.1834 - acc: 0.9219
# Epoch 9: val_loss improved from 0.29634 to 0.27481, saving model to my_checkpoint.ckpt
# 582/582 [==============================] - 49s 83ms/step - loss: 0.1833 - acc: 0.9219 - val_loss: 0.2748 - val_acc: 0.8841
# Epoch 10/20
# 581/582 [============================>.] - ETA: 0s - loss: 0.1587 - acc: 0.9372
# Epoch 10: val_loss did not improve from 0.27481
# 582/582 [==============================] - 48s 82ms/step - loss: 0.1587 - acc: 0.9372 - val_loss: 0.2901 - val_acc: 0.8910
# Epoch 11/20
# 581/582 [============================>.] - ETA: 0s - loss: 0.1368 - acc: 0.9466
# Epoch 11: val_loss did not improve from 0.27481
# 582/582 [==============================] - 49s 83ms/step - loss: 0.1367 - acc: 0.9466 - val_loss: 0.2996 - val_acc: 0.8951
# Epoch 12/20
# 581/582 [============================>.] - ETA: 0s - loss: 0.1202 - acc: 0.9533
# Epoch 12: val_loss improved from 0.27481 to 0.26278, saving model to my_checkpoint.ckpt
# 582/582 [==============================] - 48s 82ms/step - loss: 0.1201 - acc: 0.9533 - val_loss: 0.2628 - val_acc: 0.9033
# Epoch 13/20
# 581/582 [============================>.] - ETA: 0s - loss: 0.1084 - acc: 0.9575
# Epoch 13: val_loss did not improve from 0.26278
# 582/582 [==============================] - 48s 82ms/step - loss: 0.1083 - acc: 0.9575 - val_loss: 0.2835 - val_acc: 0.9033
# Epoch 14/20
# 581/582 [============================>.] - ETA: 0s - loss: 0.0968 - acc: 0.9627
# Epoch 14: val_loss did not improve from 0.26278
# 582/582 [==============================] - 47s 80ms/step - loss: 0.0967 - acc: 0.9627 - val_loss: 0.2775 - val_acc: 0.8983
# Epoch 15/20
# 581/582 [============================>.] - ETA: 0s - loss: 0.0909 - acc: 0.9657
# Epoch 15: val_loss did not improve from 0.26278
# 582/582 [==============================] - 47s 81ms/step - loss: 0.0909 - acc: 0.9657 - val_loss: 0.3153 - val_acc: 0.9033
# Epoch 16/20
# 581/582 [============================>.] - ETA: 0s - loss: 0.0805 - acc: 0.9685
# Epoch 16: val_loss did not improve from 0.26278
# 582/582 [==============================] - 47s 81ms/step - loss: 0.0804 - acc: 0.9686 - val_loss: 0.3268 - val_acc: 0.8970
# Epoch 17/20
# 581/582 [============================>.] - ETA: 0s - loss: 0.0701 - acc: 0.9722
# Epoch 17: val_loss did not improve from 0.26278
# 582/582 [==============================] - 49s 84ms/step - loss: 0.0701 - acc: 0.9722 - val_loss: 0.3067 - val_acc: 0.8975
# Epoch 18/20
# 581/582 [============================>.] - ETA: 0s - loss: 0.0660 - acc: 0.9758
# Epoch 18: val_loss did not improve from 0.26278
# 582/582 [==============================] - 48s 82ms/step - loss: 0.0659 - acc: 0.9758 - val_loss: 0.3360 - val_acc: 0.9093
# Epoch 19/20
# 581/582 [============================>.] - ETA: 0s - loss: 0.0679 - acc: 0.9744
# Epoch 19: val_loss did not improve from 0.26278
# 582/582 [==============================] - 47s 81ms/step - loss: 0.0679 - acc: 0.9744 - val_loss: 0.2944 - val_acc: 0.9043
# Epoch 20/20
# 581/582 [============================>.] - ETA: 0s - loss: 0.0577 - acc: 0.9783
# Epoch 20: val_loss did not improve from 0.26278
# 582/582 [==============================] - 47s 81ms/step - loss: 0.0576 - acc: 0.9783 - val_loss: 0.2927 - val_acc: 0.9089

# %% [markdown]
# ## 학습 완료 후 Load Weights (ModelCheckpoint)

# %% [markdown]
# 학습이 완료된 후에는 반드시 `load_weights`를 해주어야 합니다.
#
# 그렇지 않으면, 열심히 ModelCheckpoint를 만든 의미가 없습니다.

# %%
# checkpoint 를 저장한 파일명을 입력합니다.
model.load_weights(checkpoint_path)
